# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#Scrape the details of trending repositories on Github.com.
#Url = https://github.com/
#You have to find the following details:
#A) Repository title
#B) Repository description
#C) Contributors count
#D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://github.com/')

# %%
#reaching the trending option from Explore menu through code. 

menu=driver.find_element(By.XPATH,'//button[@class="Button Button--iconOnly Button--secondary Button--medium AppHeader-button color-bg-transparent p-0 color-fg-muted"]')
menu.click()

# %%
# getting explore button and clicking on it
explore = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[1]/deferred-side-panel/include-fragment/dialog-helper/dialog/scrollable-region/div/div[1]/nav/nav-list/ul/li[8]/a/span[2]')
explore.click()

# %%
# selecting trending option
trending=driver.find_element(By.XPATH,'//a[@class="js-selected-navigation-item d-inline-block py-2 py-md-3 mr-3 mr-md-4 no-underline subnav-link"][2]')
trending.click()

# %%
#scrapping repository title
repository_title=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="Link"]')
for i in title_tags:
 title=i.text
 repository_title.append(title)

# %%
repository_title
# Out:
# ['DiceDB / dice',
#  'ValdikSS / GoodbyeDPI',
#  'LibreHardwareMonitor / LibreHardwareMonitor',
#  'trimstray / the-book-of-secret-knowledge',
#  'miss-mumu / developer2gwy',
#  'GyulyVGC / sniffnet',
#  'pocketbase / pocketbase',
#  'alexta69 / metube',
#  'lipku / metahuman-stream',
#  'jwasham / coding-interview-university',
#  'drawdb-io / drawdb',
#  'opendatalab / MinerU',
#  'microsoft / qlib',
#  'recloudstream / cloudstream',
#  'projectdiscovery / nuclei',
#  'ClickHouse / ClickHouse',
#  'c3lang / c3c',
#  'xuchengsheng / spring-reading']

# %%
#scrapping Repository description

repository_description=[]

description_tags=driver.find_elements(By.XPATH,'//P[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in description_tags:
 description=i.text
 repository_description.append(description)

# %%
repository_description
# Out:
# ['A drop-in replacement of Redis with SQL-based realtime reactivity.',
#  'GoodbyeDPI — Deep Packet Inspection circumvention utility (for Windows)',
#  'Libre Hardware Monitor, home of the fork of Open Hardware Monitor',
#  'A collection of inspiring lists, manuals, cheatsheets, blogs, hacks, one-liners, cli/web tools and more.',
#  '公务员从入门到上岸，最佳程序员公考实践教程',
#  'Comfortably monitor your Internet traffic 🕵️\u200d♂️',
#  'Open Source realtime backend in 1 file',
#  'Self-hosted YouTube downloader (web UI for youtube-dl / yt-dlp)',
#  'Real time interactive streaming digital human',
#  'A complete computer science study plan to become a software engineer.',
#  'Free, simple, and intuitive online database design tool and SQL generator.',
#  'A one-stop, open-source, high-quality data extraction tool, supports PDF/webpage/e-book extraction.一站式开源高质量数据提取工具，支持PDF/网页/多格式电子书提取。',
# ...

# %%
#scrapping Contributors count
contributors_count=[]

contributors_tags=driver.find_elements(By.XPATH, '/html/body/div[1]/div[5]/main/div[3]/div/div[2]/article[1]/div[2]/a[2]')
for i in contributors_tags:
    contributors=i.text
    contributors_count.append(contributors)

# %%
contributors_count
# Out:
# ['233']

# %%
#scrapping language used

language_used=[]
language_tags=driver.find_elements(By.XPATH,'//div[@class="mb-3 mb-sm-0"]')
for i in language_tags:
    language=i.text
    language_used.append(language)

# %%
language_used
# Out:
# ['Language: Any']

# %%
#5. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/ You have to find the following details:
#A) Song name
#B) Artist name
#C) Last week rank
#D) Peak rank
#E) Weeks on board 
#Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver.get('https:/www.billboard.com/')

# %%
#Getting to the charts option

charts=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
charts.click()

# %%
#Getting to the hot 100 page

hot_100__page=driver.find_element(By.XPATH,'//a[@class="c-link  lrv-a-unstyle-link lrv-u-background-color-brand-secondary-dark lrv-u-color-grey-lightest lrv-u-color-grey-lightest:hover lrv-u-width-100p lrv-u-text-align-center lrv-a-hover-effect lrv-u-background-color-grey-dark:hover a-font-accent-fancy lrv-u-font-size-20 u-padding-tb-15 u-letter-spacing-0112 lrv-a-icon-after a-icon-magazine lrv-u-justify-content-center lrv-u-align-items-center lrv-a-unstyle-link u-width-100p@tablet u-width-235@mobile-max lrv-u-margin-t-050@mobile-max u-background-color-white@mobile-max u-color-black@mobile-max lrv-u-border-a-1@mobile-max lrv-u-border-color-brand-accent-red u-line-height-1"]')
hot_100__page.click()

# %%
#Scrapping song name

songs_names=[]
songs_tags=driver.find_elements(By.XPATH,'//h3[@id="title-of-a-story"]')
for i in songs_tags:
    songs=i.text
    songs_names.append(songs)

# %%
songs_names
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'A Bar Song (Tipsy)',
#  '',
#  '',
#  '',
#  'I Had Some Help',
#  '',
#  '',
#  '',
#  'Not Like Us',
#  '',
#  '',
#  '',
#  'Million Dollar Baby',
#  '',
#  '',
#  '',
#  'Espresso',
#  '',
#  '',
#  '',
#  'Too Sweet',
#  '',
#  '',
#  '',
#  'Please Please Please',
#  '',
#  '',
#  '',
#  'Lose Control',
#  '',
#  '',
#  '',
#  'Beautiful Things',
#  '',
#  '',
#  '',
#  'Good Luck, Babe!',
#  '',
#  '',
#  '',
#  'Birds Of A Feather',
#  '',
#  '',
#  '',
#  'Lies Lies Lies',
#  '',
#  '',
#  '',
#  "Ain't No Love In Oklahoma",
#  '',
#  '',
#  '',
#  'Who',
#  '',
#  '',
#  '',
#  'Cowgirls',
#  '',
#  '',
#  '',
#  'Pink Skies',
#  '',
#  '',
#  '',
#  'Houdini',
#  '',
#  '',
#  '',
#  '28',
#  '',
#  '',
#  '',
#  'Like That',
#  '',
#  '',
#  '',
#  'Miles On It',
#  '',
#  '',
#  '',
#  'Saturn',
#  '',
#  '',
#  '',
#  'High Road',
#  '',
#  '',
#  '',
#  'Austin',
#  '',
#  '',
#  '',
#  'I Remember Everything',
#  '',
#  '',
# ...

# %%
#scrapping artists names

artists_names=[]
names_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
for i in names_tags:
 names=i.text
 artists_names.append(names)

# %%
artists_names
# Out:
# ['Post Malone Featuring Morgan Wallen',
#  'Kendrick Lamar',
#  'Tommy Richman',
#  'Sabrina Carpenter',
#  'Hozier',
#  'Sabrina Carpenter',
#  'Teddy Swims',
#  'Benson Boone',
#  'Chappell Roan',
#  'Billie Eilish',
#  'Morgan Wallen',
#  'Luke Combs',
#  'Jimin',
#  'Morgan Wallen Featuring ERNEST',
#  'Zach Bryan',
#  'Eminem',
#  'Zach Bryan',
#  'Future, Metro Boomin & Kendrick Lamar',
#  'Marshmello & Kane Brown',
#  'SZA',
#  'Koe Wetzel & Jessie Murph',
#  'Dasha',
#  'Zach Bryan Featuring Kacey Musgraves',
#  'Taylor Swift Featuring Post Malone',
#  'Chappell Roan',
#  'GloRilla & Megan Thee Stallion',
#  'Ariana Grande',
#  'Noah Kahan',
#  'Billie Eilish',
#  'Taylor Swift',
#  'Sabrina Carpenter',
#  'Jelly Roll',
#  'Benson Boone',
#  'Karol G',
#  'Megan Thee Stallion Featuring Yuki Chiba',
#  'Jack Harlow',
#  'Post Malone Featuring Blake Shelton',
#  'Moneybagg Yo Featuring Morgan Wallen',
#  'GloRilla',
#  'FloyyMenor X Cris Mj',
#  'Nate Smith',
#  'GloRilla',
# ...

# %%
#Scrapping Last week rank 

Last_week_rank=[]

rank_tags=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1"][1]/span')
for i in rank_tags:
    rank=i.text
    Last_week_rank.append(rank)

# %%
Last_week_rank
# Out:
# ['1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '7',
#  '6',
#  '8',
#  '9',
#  '11',
#  '13',
#  '12',
#  '32',
#  '-',
#  '14',
#  '15',
#  '10',
#  '16',
#  '18',
#  '23',
#  '22',
#  '28',
#  '26',
#  '29',
#  '17',
#  '40',
#  '34',
#  '35',
#  '44',
#  '36',
#  '43',
#  '38',
#  '46',
#  '49',
#  '41',
#  '51',
#  '48',
#  '33',
#  '42',
#  '50',
#  '53',
#  '54',
#  '47',
#  '55',
#  '61',
#  '52',
#  '65',
#  '27',
#  '-',
#  '66',
#  '64',
#  '68',
#  '58',
#  '82',
#  '78',
#  '62',
#  '24',
#  '67',
#  '57',
#  '71',
#  '60',
#  '80',
#  '74',
#  '76',
#  '21',
#  '70',
#  '81',
#  '73',
#  '-',
#  '83',
#  '77',
#  '75',
#  '88',
#  '99',
#  '92',
#  '19',
#  '85',
#  '89',
#  '90',
#  '97',
#  '-',
#  '20',
#  '87',
#  '-',
#  '-',
#  '98',
#  '93',
#  '94',
#  '79',
#  '25',
#  '-',
#  '84',
#  '-',
#  '91',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-']

# %%
#Scrapping Peak rank

Peak_rank=[]
peak_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max"]')
for i in peak_tags:
    peak=i.text
    Peak_rank.append(peak)

# %%
Peak_rank
# Out:
# ['',
#  '',
#  '',
#  '2',
#  '1',
#  '11',
#  '',
#  '',
#  '',
#  '3',
#  '1',
#  '12',
#  '',
#  '',
#  '',
#  '4',
#  '2',
#  '13',
#  '',
#  '',
#  '',
#  '5',
#  '3',
#  '15',
#  '',
#  '',
#  '',
#  '7',
#  '1',
#  '18',
#  '',
#  '',
#  '',
#  '6',
#  '1',
#  '7',
#  '',
#  '',
#  '',
#  '8',
#  '1',
#  '50',
#  '',
#  '',
#  '',
#  '9',
#  '2',
#  '27',
#  '',
#  '',
#  '',
#  '11',
#  '10',
#  '16',
#  '',
#  '',
#  '',
#  '13',
#  '9',
#  '10',
#  '',
#  '',
#  '',
#  '12',
#  '7',
#  '3',
#  '',
#  '',
#  '',
#  '32',
#  '13',
#  '10',
#  '',
#  '',
#  '',
#  '-',
#  '14',
#  '1',
#  '',
#  '',
#  '',
#  '14',
#  '12',
#  '32',
#  '',
#  '',
#  '',
#  '15',
#  '6',
#  '9',
#  '',
#  '',
#  '',
#  '10',
#  '2',
#  '8',
#  '',
#  '',
#  '',
#  '16',
#  '14',
#  '3',
#  '',
#  '',
#  '',
#  '18',
#  '1',
#  '18',
#  '',
#  '',
#  '',
#  '23',
#  '20',
#  '12',
#  '',
#  '',
#  '',
#  '22',
#  '6',
#  '22',
#  '',
#  '',
#  '',
#  '28',
#  '22',
#  '7',
#  '',
#  '',
#  '',
# ...

# %%
#scrappong Weeks_on_chart

Weeks_on_chart=[]
chart_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max"]')
for i in chart_tags:
 chart=i.text
 Weeks_on_chart.append(chart)

# %%
Weeks_on_chart
# Out:
# ['',
#  '',
#  '',
#  '2',
#  '1',
#  '11',
#  '',
#  '',
#  '',
#  '3',
#  '1',
#  '12',
#  '',
#  '',
#  '',
#  '4',
#  '2',
#  '13',
#  '',
#  '',
#  '',
#  '5',
#  '3',
#  '15',
#  '',
#  '',
#  '',
#  '7',
#  '1',
#  '18',
#  '',
#  '',
#  '',
#  '6',
#  '1',
#  '7',
#  '',
#  '',
#  '',
#  '8',
#  '1',
#  '50',
#  '',
#  '',
#  '',
#  '9',
#  '2',
#  '27',
#  '',
#  '',
#  '',
#  '11',
#  '10',
#  '16',
#  '',
#  '',
#  '',
#  '13',
#  '9',
#  '10',
#  '',
#  '',
#  '',
#  '12',
#  '7',
#  '3',
#  '',
#  '',
#  '',
#  '32',
#  '13',
#  '10',
#  '',
#  '',
#  '',
#  '-',
#  '14',
#  '1',
#  '',
#  '',
#  '',
#  '14',
#  '12',
#  '32',
#  '',
#  '',
#  '',
#  '15',
#  '6',
#  '9',
#  '',
#  '',
#  '',
#  '10',
#  '2',
#  '8',
#  '',
#  '',
#  '',
#  '16',
#  '14',
#  '3',
#  '',
#  '',
#  '',
#  '18',
#  '1',
#  '18',
#  '',
#  '',
#  '',
#  '23',
#  '20',
#  '12',
#  '',
#  '',
#  '',
#  '22',
#  '6',
#  '22',
#  '',
#  '',
#  '',
#  '28',
#  '22',
#  '7',
#  '',
#  '',
#  '',
# ...

# %%
driver.quit()

# %%
#Scrape the details of Highest selling novels.
#A) Book name
#B) Author name
#C) Volumes sold
#D) Publisher
#E) Genre
 # Url - https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/')

# %%
#scrapping the book names

book_names=[]
book_tags=driver.find_elements(By.XPATH,'//td[@class="left"][2]')
for i in book_tags:
    book=i.text
    book_names.append(book)

# %%
book_names
# Out:
# ['Da Vinci Code,The',
#  'Harry Potter and the Deathly Hallows',
#  "Harry Potter and the Philosopher's Stone",
#  'Harry Potter and the Order of the Phoenix',
#  'Fifty Shades of Grey',
#  'Harry Potter and the Goblet of Fire',
#  'Harry Potter and the Chamber of Secrets',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Angels and Demons',
#  "Harry Potter and the Half-blood Prince:Children's Edition",
#  'Fifty Shades Darker',
#  'Twilight',
#  'Girl with the Dragon Tattoo,The:Millennium Trilogy',
#  'Fifty Shades Freed',
#  'Lost Symbol,The',
#  'New Moon',
#  'Deception Point',
#  'Eclipse',
#  'Lovely Bones,The',
#  'Curious Incident of the Dog in the Night-time,The',
#  'Digital Fortress',
#  'Short History of Nearly Everything,A',
#  'Girl Who Played with Fire,The:Millennium Trilogy',
#  'Breaking Dawn',
#  'Very Hungry Caterpillar,The:The Very Hungry Caterpillar',
#  'Gruffalo,The',
#  "Jamie's 30-Minute Meals",
#  'Kite Runner,The',
#  'One Day',
# ...

# %%
#scrapping Author_name

Author_name=[]
author_tags=driver.find_elements(By.XPATH,'//TD[@class="left"][3]')
for i in author_tags:
    author=i.text
    Author_name.append(author)

# %%
Author_name
# Out:
# ['Brown, Dan',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'James, E. L.',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'Brown, Dan',
#  'Rowling, J.K.',
#  'James, E. L.',
#  'Meyer, Stephenie',
#  'Larsson, Stieg',
#  'James, E. L.',
#  'Brown, Dan',
#  'Meyer, Stephenie',
#  'Brown, Dan',
#  'Meyer, Stephenie',
#  'Sebold, Alice',
#  'Haddon, Mark',
#  'Brown, Dan',
#  'Bryson, Bill',
#  'Larsson, Stieg',
#  'Meyer, Stephenie',
#  'Carle, Eric',
#  'Donaldson, Julia',
#  'Oliver, Jamie',
#  'Hosseini, Khaled',
#  'Nicholls, David',
#  'Hosseini, Khaled',
#  'Larsson, Stieg',
#  'Niffenegger, Audrey',
#  'McEwan, Ian',
#  'Fielding, Helen',
#  'Clarkson, Jeremy',
#  'Bernieres, Louis de',
#  'Kay, Peter',
#  'Martel, Yann',
#  'Stephenson, Pamela',
#  'Pelzer, Dave',
#  'Donaldson, Julia',
#  'McCourt, Frank',
#  'Faulks, Sebastian',
#  'Pullman, Philip',
#  'Mosse, Kate',
#  'Rowling, J.K.',
#  'Stockett, Kathryn',
#  'Parsons, Tony',
# ...

# %%
#Scrapping Volumes sold

Volumes_sold=[]
volume_tags=driver.find_elements(By.XPATH,'//td[@class="left"][4]')
for i in volume_tags:
    volume=i.text
    Volumes_sold.append(volume)

# %%
Volumes_sold
# Out:
# ['5,094,805',
#  '4,475,152',
#  '4,200,654',
#  '4,179,479',
#  '3,758,936',
#  '3,583,215',
#  '3,484,047',
#  '3,377,906',
#  '3,193,946',
#  '2,950,264',
#  '2,479,784',
#  '2,315,405',
#  '2,233,570',
#  '2,193,928',
#  '2,183,031',
#  '2,152,737',
#  '2,062,145',
#  '2,052,876',
#  '2,005,598',
#  '1,979,552',
#  '1,928,900',
#  '1,852,919',
#  '1,814,784',
#  '1,787,118',
#  '1,783,535',
#  '1,781,269',
#  '1,743,266',
#  '1,629,119',
#  '1,616,068',
#  '1,583,992',
#  '1,555,135',
#  '1,546,886',
#  '1,539,428',
#  '1,508,205',
#  '1,489,403',
#  '1,352,318',
#  '1,310,207',
#  '1,310,176',
#  '1,231,957',
#  '1,217,712',
#  '1,208,711',
#  '1,204,058',
#  '1,184,967',
#  '1,181,503',
#  '1,181,093',
#  '1,153,181',
#  '1,132,336',
#  '1,130,802',
#  '1,126,337',
#  '1,115,549',
#  '1,108,328',
#  '1,107,379',
#  '1,104,403',
#  '1,092,349',
#  '1,090,847',
#  '1,087,262',
#  '1,054,196',
#  '1,037,160',
#  '1,023,688',
#  '1,015,956',
#  '1,009,873',
#  '1,004,414',
# ...

# %%
#scrapping Publishers

publishers=[]
publisher_tags=driver.find_elements(By.XPATH,'//td[@class="left"][5]')
for i in publisher_tags:
    publisher=i.text
    publishers.append(publisher)

# %%
publishers
# Out:
# ['Transworld',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Random House',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Transworld',
#  'Bloomsbury',
#  'Random House',
#  'Little, Brown Book',
#  'Quercus',
#  'Random House',
#  'Transworld',
#  'Little, Brown Book',
#  'Transworld',
#  'Little, Brown Book',
#  'Pan Macmillan',
#  'Random House',
#  'Transworld',
#  'Transworld',
#  'Quercus',
#  'Little, Brown Book',
#  'Penguin',
#  'Pan Macmillan',
#  'Penguin',
#  'Bloomsbury',
#  'Hodder & Stoughton',
#  'Bloomsbury',
#  'Quercus',
#  'Random House',
#  'Random House',
#  'Pan Macmillan',
#  'Penguin',
#  'Random House',
#  'Random House',
#  'Canongate',
#  'HarperCollins',
#  'Orion',
#  'Pan Macmillan',
#  'HarperCollins',
#  'Random House',
#  'Scholastic Ltd.',
#  'Orion',
#  'Bloomsbury',
#  'Penguin',
#  'HarperCollins',
#  'Random House',
#  'Little, Brown Book',
#  'Headline',
#  'HarperCollins',
#  'Penguin',
#  'Orion',
#  'Bloomsbury',
# ...

# %%
#Scrapping Genre

Genre=[]
genre_tags=driver.find_elements(By.XPATH,'//td[@class="last left"]')
for i in genre_tags:
    genre=i.text
    Genre.append(genre)

# %%
Genre
# Out:
# ['Crime, Thriller & Adventure',
#  "Children's Fiction",
#  "Children's Fiction",
#  "Children's Fiction",
#  'Romance & Sagas',
#  "Children's Fiction",
#  "Children's Fiction",
#  "Children's Fiction",
#  'Crime, Thriller & Adventure',
#  "Children's Fiction",
#  'Romance & Sagas',
#  'Young Adult Fiction',
#  'Crime, Thriller & Adventure',
#  'Romance & Sagas',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'Crime, Thriller & Adventure',
#  'Popular Science',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'Picture Books',
#  'Picture Books',
#  'Food & Drink: General',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'Crime, Thriller & Adventure',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
# ...

# %%
driver.quit()

# %%
#Scrape the details most watched tv series of all time from imdb.com.
#Url = https://www.imdb.com/list/ls095964455/ You have to find the following details:
#A) Name
#B) Year span
#C) Genre
#D) Run time
#E) Ratings
#F) Votes

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
#Scrapping Name

Name=[]
name_tags=driver.find_elements(By.XPATH,'//a[@class="ipc-poster-card__title ipc-poster-card__title--clamp-1 ipc-poster-card__title--clickable"]')
for i in name_tags:
    name=i.text
    Name.append(name)

# %%
Name
# Out:
# ['1. Deadpool & Wolverine',
#  '2. House of the Dragon',
#  '3. Twisters',
#  '4. The Boys',
#  '5. Longlegs',
#  '6. Presumed Innocent',
#  '7. Those About to Die',
#  '8. The Bear',
#  '9. Cobra Kai',
#  '10. Game of Thrones',
#  'Deadpool & Wolverine',
#  'Twisters',
#  'Kaiva',
#  'Presumed Innocent',
#  'Longlegs',
#  'House of the Dragon',
#  'Inside Out 2',
#  'Maharaja',
#  'The Boys',
#  'Furiosa: A Mad Max Saga',
#  'Deadpool',
#  'Deadpool 2',
#  'Dune: Part Two',
#  'Kingdom of the Planet of the Apes',
#  'Breaking Bad',
#  'Game of Thrones',
#  'Civil War',
#  'Kill',
#  'Fallout',
#  'Logan',
#  'Oppenheimer',
#  'Interstellar',
#  'The Dark Knight',
#  'The Shawshank Redemption',
#  'Kafas',
#  'Fight Club',
#  'Joker',
#  'Inside Out',
#  'The Bear',
#  'Gladiator',
#  'The Boys',
#  'Those About to Die',
#  'The Ministry of Ungentlemanly Warfare',
#  'Land of Bad',
#  'My Spy: The Eternal City',
#  'My Lady Jane',
#  'Supernatural',
#  'Fallout',
# ...

# %%
#Scrapping Year span

Year_span=[]
#No year span on the page

# %%
Year_span
# Out:
# []

# %%
#scrapping genre

Genre=[]
genre_tags=driver.find_elements(By.XPATH,'//div[@class="trailers-button-text"]')
for i in genre_tags:
    genre=i.text
    Genre.append(genre)

# %%
Genre
# Out:
# ['Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
#  'Trailer',
# ...

# %%
#scrapping Run time 

Run_time=[]
#No run time on the page

# %%
Run_time
# Out:
# []

# %%
#scrapping ratings

Ratings=[]
rating_tags=driver.find_elements(By.XPATH,'//span[@class="ipc-rating-star--rating"]')
for i in rating_tags:
    rating=i.text
    Ratings.append(rating)

# %%
Ratings
# Out:
# ['8.2',
#  '8.4',
#  '7.1',
#  '8.7',
#  '7.2',
#  '7.8',
#  '6.5',
#  '8.6',
#  '8.5',
#  '9.2',
#  '8.2',
#  '7.1',
#  '8.5',
#  '7.8',
#  '7.2',
#  '8.4',
#  '7.8',
#  '8.7',
#  '8.7',
#  '7.6',
#  '8.0',
#  '7.6',
#  '8.5',
#  '7.0',
#  '9.5',
#  '9.2',
#  '7.1',
#  '7.7',
#  '8.4',
#  '8.1',
#  '8.3',
#  '8.7',
#  '9.0',
#  '9.3',
#  '8.2',
#  '8.8',
#  '8.4',
#  '8.1',
#  '8.6',
#  '8.5',
#  '8.7',
#  '6.5',
#  '6.8',
#  '6.6',
#  '5.6',
#  '7.4',
#  '8.4',
#  '8.4',
#  '8.1',
#  '7.7',
#  '8.3',
#  '8.5',
#  '8.7',
#  '6.9',
#  '9.0',
#  '7.8',
#  '8.1',
#  '8.9',
#  '7.1',
#  '8.5',
#  '8.5',
#  '9.3',
#  '8.0',
#  '5.7',
#  '7.8',
#  '6.3',
#  '8.2',
#  '7.8',
#  '7.1',
#  '7.4',
#  '7.2',
#  '7.5',
#  '6.3',
#  '8.1',
#  '7.4',
#  '8.8',
#  '8.2',
#  '6.6',
#  '6.9',
#  '7.4',
#  '6.2',
#  '8.7',
#  '7.4',
#  '6.5',
#  '5.7',
#  '7.3',
#  '7.8',
#  '7.0',
#  '8.9',
#  '6.5',
#  '6.6']

# %%
#scrapping votes

votes=[]
#No votes on the page

# %%
votes
# Out:
# []

# %%
driver.quit()

# %%
#8. Details of Datasets from UCI machine learning repositories.
#Url = https://archive.ics.uci.edu/ You have to find the following details:
#A) Dataset name
#B) Data type
#C) Task
#D) Attribute type
#E) No of instances
#F) No of attribute 
#G) Year
 #Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://archive.ics.uci.edu/')

# %%
#getting to the show all data page

search = driver.find_element(By.CLASS_NAME,"search")
search.send_keys('search')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[476], line 3
#       1 #getting to the show all data page
# ----> 3 search = driver.find_element(By.CLASS_NAME,"search")
#       4 search.send_keys('search')
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
# ...
